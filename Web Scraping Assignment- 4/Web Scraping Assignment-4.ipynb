# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\pritam shet\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\pritam shet\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pritam shet\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.2.post1)
# Requirement already satisfied: requests in c:\users\pritam shet\anaconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pritam shet\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pritam shet\anaconda3\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\pritam shet\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pritam shet\anaconda3\lib\site-packages (from requests) (2022.12.7)

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\pritam shet\anaconda3\lib\site-packages (4.16.0)
# Requirement already satisfied: trio~=0.17 in c:\users\pritam shet\anaconda3\lib\site-packages (from selenium) (0.23.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\pritam shet\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\pritam shet\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\pritam shet\anaconda3\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\pritam shet\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\pritam shet\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: idna in c:\users\pritam shet\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sortedcontainers in c:\users\pritam shet\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\pritam shet\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\pritam shet\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\pritam shet\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\pritam shet\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\pritam shet\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\pritam shet\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\pritam shet\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia. Url
# = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details: A)
# Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
#opening the website page
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
#Extracting Rank
rank=[i.text.strip('.') for i in driver.find_elements(By.XPATH,'//tbody/tr/td[1]')[:30]]

#Extracting Name
name =[i.text.split('[')[0] for i in driver.find_elements(By.XPATH,'//tr/td[2]')[:30]]

#Extracting Artist
artist = [i.text for i in driver.find_elements(By.XPATH,'//tr/td[3]')[:30]]

#extracting views
viewsBillions =[i.text for i in driver.find_elements(By.XPATH,'//tr/td[4]')[:30]]

#extracting Upload Date
uploadDate=[i.text for i in driver.find_elements(By.XPATH,'//tr/td[5]')[:30]]

driver.close()

print(len(rank),len(name),len(artist),len(viewsBillions),len(uploadDate))
# Out:
# 30 30 30 30 30

# %%
Most_viewed_videos_on_YouTube = pd.DataFrame({
    "Rank":rank,
    "Name": name,
    "Artist": artist,
    "Upload Date": uploadDate,
    "Views In Billions": viewsBillions
})

#set rank as index
Most_viewed_videos_on_YouTube = Most_viewed_videos_on_YouTube.set_index('Rank')
Most_viewed_videos_on_YouTube
# Out:
#                                                                                               Name  \
# Rank
# "Baby Shark Dance"[6]                                  Pinkfong Baby Shark - Kids' Songs & Stories
# "Despacito"[9]                                                                          Luis Fonsi
# "Johny Johny Yes Papa"[17]                       LooLoo Kids - Nursery Rhymes and Children's Songs
# "Bath Song"[18]                                                         Cocomelon - Nursery Rhymes
# "Shape of You"[19]                                                                      Ed Sheeran
# "See You Again"[22]                                                                    Wiz Khalifa
# "Wheels on the Bus"[27]                                                 Cocomelon - Nursery Rhymes
# "Phonics Song with Two Words"[28]                            ChuChu TV Nursery Rhymes & Kids Songs
# "Uptown Funk"[29]                                                                      Mark Ronson
# "Learning Colors – Colorful Eggs on a Farm"[30]                                        Miroshka TV
# "Gangnam Style"[31]                                                                            Psy
# "Masha and the Bear – Recipe for Disaster"[36]                                          Get Movies
# "Dame Tu Cosita"[37]                                                                 Ultra Records
# "Axel F"[38]                                                                            Crazy Frog
# "Sugar"[39]                                                                               Maroon 5
# "Counting Stars"[40]                                                                   OneRepublic
# "Roar"[41]                                                                              Katy Perry
# "Baa Baa Black Sheep"[42]                                               Cocomelon - Nursery Rhymes
# "Lakdi Ki Kathi"[43]                                                                  Jingle Toons
# "Waka Waka (This Time for Africa)"[44]                                                     Shakira
# "Sorry"[45]                                                                          Justin Bieber
# "Thinking Out Loud"[46]                                                                 Ed Sheeran
# "Humpty the train on a fruits ride"[47]              Kiddiestv Hindi - Nursery Rhymes & Kids Songs
# "Dark Horse"[48]                                                                        Katy Perry
# "Perfect"[49]                                                                           Ed Sheeran
# "Shree Hanuman Chalisa"[50]                                                  T-Series Bhakti Sagar
# "Let Her Go"[51]                                                                         Passenger
# "Faded"[52]                                                                            Alan Walker
# "Girls Like You"[53]                                                                      Maroon 5
# "Lean On"[54]                                                                 Major Lazer Official
#
#                                                 Artist Upload Date  \
# Rank
# "Baby Shark Dance"[6]                            13.84         [A]
# "Despacito"[9]                                    8.34         [B]
# "Johny Johny Yes Papa"[17]                        6.86
# "Bath Song"[18]                                   6.55
# "Shape of You"[19]                                6.17         [C]
# "See You Again"[22]                               6.13         [D]
# "Wheels on the Bus"[27]                           5.79
# "Phonics Song with Two Words"[28]                 5.63
# "Uptown Funk"[29]                                 5.12
# "Learning Colors – Colorful Eggs on a Farm"[30]   5.04
# "Gangnam Style"[31]                               5.00         [E]
# "Masha and the Bear – Recipe for Disaster"[36]    4.57
# "Dame Tu Cosita"[37]                              4.51
# "Axel F"[38]                                      4.24
# "Sugar"[39]                                       3.98
# "Counting Stars"[40]                              3.94
# "Roar"[41]                                        3.93
# "Baa Baa Black Sheep"[42]                         3.90
# "Lakdi Ki Kathi"[43]                              3.82
# "Waka Waka (This Time for Africa)"[44]            3.81
# "Sorry"[45]                                       3.75
# "Thinking Out Loud"[46]                           3.71
# "Humpty the train on a fruits ride"[47]           3.68
# "Dark Horse"[48]                                  3.65
# "Perfect"[49]                                     3.63
# "Shree Hanuman Chalisa"[50]                       3.61
# "Let Her Go"[51]                                  3.58
# "Faded"[52]                                       3.57
# "Girls Like You"[53]                              3.54
# "Lean On"[54]                                     3.52
#
#                                                  Views In Billions
# Rank
# "Baby Shark Dance"[6]                                June 17, 2016
# "Despacito"[9]                                    January 12, 2017
# "Johny Johny Yes Papa"[17]                         October 8, 2016
# "Bath Song"[18]                                        May 2, 2018
# "Shape of You"[19]                                January 30, 2017
# "See You Again"[22]                                  April 6, 2015
# "Wheels on the Bus"[27]                               May 24, 2018
# "Phonics Song with Two Words"[28]                    March 6, 2014
# "Uptown Funk"[29]                                November 19, 2014
# "Learning Colors – Colorful Eggs on a Farm"[30]  February 27, 2018
# "Gangnam Style"[31]                                  July 15, 2012
# "Masha and the Bear – Recipe for Disaster"[36]    January 31, 2012
# "Dame Tu Cosita"[37]                                 April 5, 2018
# "Axel F"[38]                                         June 16, 2009
# "Sugar"[39]                                       January 14, 2015
# "Counting Stars"[40]                                  May 31, 2013
# "Roar"[41]                                       September 5, 2013
# "Baa Baa Black Sheep"[42]                            June 25, 2018
# "Lakdi Ki Kathi"[43]                                 June 14, 2018
# "Waka Waka (This Time for Africa)"[44]                June 4, 2010
# "Sorry"[45]                                       October 22, 2015
# "Thinking Out Loud"[46]                            October 7, 2014
# "Humpty the train on a fruits ride"[47]           January 26, 2018
# "Dark Horse"[48]                                 February 20, 2014
# "Perfect"[49]                                     November 9, 2017
# "Shree Hanuman Chalisa"[50]                           May 10, 2011
# "Let Her Go"[51]                                     July 25, 2012
# "Faded"[52]                                       December 3, 2015
# "Girls Like You"[53]                                  May 31, 2018
# "Lean On"[54]                                       March 22, 2015

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Series
# B) Place
# C) Date
# D) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
#opening the website page
driver.get("https://www.bcci.tv/")

# %%
#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementClickInterceptedException

# %%
#opening the International Page
international = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
international.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[26], line 2
#       1 #opening the International Page
# ----> 2 international = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
#       3 international.click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:742, in WebDriver.find_element(self, by, value)
#     739     by = By.CSS_SELECTOR
#     740     value = f'[name="{value}"]'
# --> 742 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#     350     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a"}
#   (Session info: chrome=120.0.6099.130); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF72DAE2142+3514994]
# 	(No symbol) [0x00007FF72D700CE2]
# 	(No symbol) [0x00007FF72D5A76AA]
# 	(No symbol) [0x00007FF72D5F1860]
# 	(No symbol) [0x00007FF72D5F197C]
# 	(No symbol) [0x00007FF72D634EE7]
# 	(No symbol) [0x00007FF72D61602F]
# 	(No symbol) [0x00007FF72D6328F6]
# 	(No symbol) [0x00007FF72D615D93]
# 	(No symbol) [0x00007FF72D5E4BDC]
# 	(No symbol) [0x00007FF72D5E5C64]
# 	GetHandleVerifier [0x00007FF72DB0E16B+3695259]
# 	GetHandleVerifier [0x00007FF72DB66737+4057191]
# 	GetHandleVerifier [0x00007FF72DB5E4E3+4023827]
# 	GetHandleVerifier [0x00007FF72D8304F9+689705]
# 	(No symbol) [0x00007FF72D70C048]
# 	(No symbol) [0x00007FF72D708044]
# 	(No symbol) [0x00007FF72D7081C9]
# 	(No symbol) [0x00007FF72D6F88C4]
# 	BaseThreadInitThunk [0x00007FFCB4D6257D+29]
# 	RtlUserThreadStart [0x00007FFCB6B0AA58+40]

# %%
#accepting cooking
try:
    cookie=driver.find_element(By.XPATH,'//button[@class="cookie__accept btn btn-primary"]')
    cookie.click()
except NoSuchElementException:
    print('No Exception Occured')

# CLicking more button
while(True):
    try:
        more = driver.find_element(By.XPATH,'//button[@class="match-btn btn-red d-flex align-items-center justify-content-center mx-auto mt-3"]')
        more.click()
    except NoSuchElementException:
        break
        
#Extracting match Title
match=[i.text.strip(' -') for i in driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')]

#Extracting Series
series = [i.text for i in driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')]

#Extracting Place
place = [i.text.split(' -')[1] for i in driver.find_elements(By.XPATH,'//div[@class="match-place ng-scope"]')]

# Extracting Date
date = [i.text for i in driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')]

# Extracting Time
time = [i.text for i in driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')]

driver.close()

print(len(match),len(series),len(place),len(date),len(time))

internationalfixtures=pd.DataFrame({
    "Match Title": match,
    "Series": series,
    "Place": place,
    "Date": date,
    "Time":time
})
internationalfixtures
# Out:
# No Exception Occured
# 0 0 0 0 0
# Empty DataFrame
# Columns: [Match Title, Series, Place, Date, Time]
# Index: []

# %% [markdown]
# 3. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details: A) Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
#opening the website page
driver.get("https://www.statisticstimes.com/")

# %%
#clicking Economy
economy=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
economy.click()

#Clicking on India
india=driver.find_element(By.XPATH,'//div[@class="dropdown-content"]/a[3]')
india.click()

# %%
GDP=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
GDP.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 GDP=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
#       2 GDP.click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:742, in WebDriver.find_element(self, by, value)
#     739     by = By.CSS_SELECTOR
#     740     value = f'[name="{value}"]'
# --> 742 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#     350     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a"}
#   (Session info: chrome=120.0.6099.130); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF72DAE2142+3514994]
# 	(No symbol) [0x00007FF72D700CE2]
# 	(No symbol) [0x00007FF72D5A76AA]
# 	(No symbol) [0x00007FF72D5F1860]
# 	(No symbol) [0x00007FF72D5F197C]
# 	(No symbol) [0x00007FF72D634EE7]
# 	(No symbol) [0x00007FF72D61602F]
# 	(No symbol) [0x00007FF72D6328F6]
# 	(No symbol) [0x00007FF72D615D93]
# 	(No symbol) [0x00007FF72D5E4BDC]
# 	(No symbol) [0x00007FF72D5E5C64]
# 	GetHandleVerifier [0x00007FF72DB0E16B+3695259]
# 	GetHandleVerifier [0x00007FF72DB66737+4057191]
# 	GetHandleVerifier [0x00007FF72DB5E4E3+4023827]
# 	GetHandleVerifier [0x00007FF72D8304F9+689705]
# 	(No symbol) [0x00007FF72D70C048]
# 	(No symbol) [0x00007FF72D708044]
# 	(No symbol) [0x00007FF72D7081C9]
# 	(No symbol) [0x00007FF72D6F88C4]
# 	BaseThreadInitThunk [0x00007FFCB4D6257D+29]
# 	RtlUserThreadStart [0x00007FFCB6B0AA58+40]

# %%
#Extracting the details
rank = []
state = []
gsdp_18 = []
gsdp_19 = []
shares = []
gdp = []

#Extracting the rank details
try:
    rank_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[1]")
    for ra in rank_tags:
        rank.append(ra.text)
except NoSuchElementException:
    Company.append('NA')
    
#Extracting state name details
try:
    state_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[2]")
    for st in state_tags:
        state.append(st.text)
except NoSuchElementException:
    Company.append('NA')

#Extracting gsdp 2019-20
try:
    gsdp_19_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[3]")
    for g in gsdp_19_tags:
        gsdp_19.append(g.text)
except NoSuchElementException:
    Company.append('NA')

#Extracting gsdp 2018-19
try:
    gsdp_18_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[4]")
    for gs in gsdp_18_tags:
        gsdp_18.append(gs.text)
except NoSuchElementException:
    Company.append('NA')
    
#Extracting share details
try:
    shares_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[5]")
    for sh in shares_tags:
        shares.append(sh.text)
except NoSuchElementException:
    Company.append('NA')

#Extracting GDP details
try:
    gdp_tags = driver.find_elements(By.XPATH,"//div[@id = 'table_id_wrapper']/table/tbody/tr/td[6]")
    for gd in gdp_tags:
        gdp.append(gd.text)
except NoSuchElementException:
    Company.append('NA')

gdp_india = pd.DataFrame({'Rank':rank,'State':state,'GSDP 2019-20(Cr INR at Current Price)':gsdp_19,'GSDP 2018-19(Cr INR at Current Price)':gsdp_18,'Share(%)':shares,'GDP($billion)':gdp})
gdp_india
# Out:
# Empty DataFrame
# Columns: [Rank, State, GSDP 2019-20(Cr INR at Current Price), GSDP 2018-19(Cr INR at Current Price), Share(%), GDP($billion)]
# Index: []

# %% [markdown]
# 4. Scrape the details of trending repositories on Github.com. Url = https://github.com/ You have to find the following details:
# Repository title
# Repository description
# Contributors count
# Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
#opening the website page
driver.get("https://github.com/")

# %%
#Clicking Open Source
source =driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
source.click()

#clicking Trending
trending=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')
trending.click()

# %%
#Extracting title
title=[i.text for i in driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]')]

#Extracting Description
description = []

for item in driver.find_elements(By.XPATH, '//article[@class="Box-row"]'):
    try:
        des = item.find_element(By.XPATH, './/p[@class="col-9 color-fg-muted my-1 pr-4"]')
        description.append(des.text)
    except NoSuchElementException:
        description.append('-')
        
#Extracting Contributors count
count=[i.text for i in driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]/a')]
contri=count[::2]

#Extracting Language
lang = []
for items in driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]'):
    try:
        l= items.find_element(By.XPATH,'./span/span[2]')
        lang.append(l.text)
    except NoSuchElementException:
        lang.append('-')
        
driver.close()
print(len(title), len(description), len(contri), len(lang))

#Converting it into DataFrame:
trending_repositories = pd.DataFrame({
    "Repository Title":title,
    "Repository Description": description,
    "Contributors Count" : contri,
    "Language" : lang
})

trending_repositories
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 #Extracting title
# ----> 2 title=[i.text for i in driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]')]
#       4 #Extracting Description
#       5 description = []
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:772, in WebDriver.find_elements(self, by, value)
#     768     value = f'[name="{value}"]'
#     770 # Return empty list if driver returns null
#     771 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 772 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#     350     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id
# Stacktrace:
# 	GetHandleVerifier [0x00007FF72DAE2142+3514994]
# 	(No symbol) [0x00007FF72D700CE2]
# 	(No symbol) [0x00007FF72D5A74C3]
# 	(No symbol) [0x00007FF72D5E412A]
# 	(No symbol) [0x00007FF72D615EC9]
# 	(No symbol) [0x00007FF72D60ECA2]
# 	(No symbol) [0x00007FF72D60E5E3]
# 	(No symbol) [0x00007FF72D576315]
# 	GetHandleVerifier [0x00007FF72DB0E16B+3695259]
# 	GetHandleVerifier [0x00007FF72DB66737+4057191]
# 	GetHandleVerifier [0x00007FF72DB5E4E3+4023827]
# 	GetHandleVerifier [0x00007FF72D8304F9+689705]
# 	(No symbol) [0x00007FF72D70C048]
# 	(No symbol) [0x00007FF72D575103]
# 	GetHandleVerifier [0x00007FF72DBAE958+4352648]
# 	BaseThreadInitThunk [0x00007FFCB4D6257D+29]
# 	RtlUserThreadStart [0x00007FFCB6B0AA58+40]

# %% [markdown]
# 5. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/ You have to find the following details:
# Song name
# Artist name
# Last week rank
# Peak rank
# Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code

# %%
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
#opening the website page
driver.get("https://www.billboard.com/")

# %%
#Clicking on the menu
menu=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[1]/div[1]/button')
menu.click()

# %%
#Clicking top 100
top = driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]/a')
top.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[45], line 2
#       1 #Clicking top 100
# ----> 2 top = driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]/a')
#       3 top.click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:742, in WebDriver.find_element(self, by, value)
#     739     by = By.CSS_SELECTOR
#     740     value = f'[name="{value}"]'
# --> 742 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#     350     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]/a"}
#   (Session info: chrome=120.0.6099.130); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF72DAE2142+3514994]
# 	(No symbol) [0x00007FF72D700CE2]
# 	(No symbol) [0x00007FF72D5A76AA]
# 	(No symbol) [0x00007FF72D5F1860]
# 	(No symbol) [0x00007FF72D5F197C]
# 	(No symbol) [0x00007FF72D634EE7]
# 	(No symbol) [0x00007FF72D61602F]
# 	(No symbol) [0x00007FF72D6328F6]
# 	(No symbol) [0x00007FF72D615D93]
# 	(No symbol) [0x00007FF72D5E4BDC]
# 	(No symbol) [0x00007FF72D5E5C64]
# 	GetHandleVerifier [0x00007FF72DB0E16B+3695259]
# 	GetHandleVerifier [0x00007FF72DB66737+4057191]
# 	GetHandleVerifier [0x00007FF72DB5E4E3+4023827]
# 	GetHandleVerifier [0x00007FF72D8304F9+689705]
# 	(No symbol) [0x00007FF72D70C048]
# 	(No symbol) [0x00007FF72D708044]
# 	(No symbol) [0x00007FF72D7081C9]
# 	(No symbol) [0x00007FF72D6F88C4]
# 	BaseThreadInitThunk [0x00007FFCB4D6257D+29]
# 	RtlUserThreadStart [0x00007FFCB6B0AA58+40]

# %%
#Extracting Required Data
data=[i.text.split('\n') for i in driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]')]

driver.close()

#Creating DataFrame:
columns = ['Song name', 'Artist Name', 'Last Weak Rank', 'Peak Rank', 'Weeks on Chart']

Top100 = pd.DataFrame(data, columns=columns)
Top100
# Out:
# Empty DataFrame
# Columns: [Song name, Artist Name, Last Weak Rank, Peak Rank, Weeks on Chart]
# Index: []
